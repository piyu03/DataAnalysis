# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\piyul\\Desktop\\kaggle\\Latest_file.csv")
df.head()
# Out:
# C:\Users\piyul\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    BASELINE_PRICE EFFECTIVE_DATE      PART_NUMBER  Count  SAP_SITE_ID
# 0             0.0       3-Jan-19     613-1340-001    1.0       1095.0
# 1             0.0       3-Jan-19     434-0015-013    1.0       1095.0
# 2             0.0       3-Jan-19  HS0-508BRH-Q//G    1.0       1095.0
# 3             0.0       3-Jan-19     440-1172-001    3.0       1095.0
# 4             0.0       3-Jan-19     150-5003-069    1.0       1095.0

# %%
df=df.dropna()
df.tail()
# Out:
#        BASELINE_PRICE EFFECTIVE_DATE      PART_NUMBER  Count  SAP_SITE_ID
# 82214       181750.00       1-Jan-19     56008944-301    2.0       1045.0
# 82215       195632.27       2-Jan-19     22010120-005    2.0       1065.0
# 82216       195632.27       1-Jan-19     22010120-005    2.0       1065.0
# 82217       246099.33       2-Jan-19  22010120-001//U    2.0       1065.0
# 82218       246099.33       1-Jan-19  22010120-001//U    2.0       1065.0

# %%
df['EFFECTIVE_DATE'] = pd.to_datetime(df['EFFECTIVE_DATE'])

# %%
df.to_csv("C:\\Users\\piyul\\Desktop\\kaggle\\filtered_dataset.csv")

# %%
col=["base_price","date","part_num","count","sap_id"]

# %%
df= pd.read_csv("C:\\Users\\piyul\\Desktop\\kaggle\\filtered_dataset.csv",names=col,header=0)
df.head()
# Out:
#    base_price        date         part_num  count  sap_id
# 0         0.0  2019-01-03     613-1340-001    1.0  1095.0
# 1         0.0  2019-01-03     434-0015-013    1.0  1095.0
# 2         0.0  2019-01-03  HS0-508BRH-Q//G    1.0  1095.0
# 3         0.0  2019-01-03     440-1172-001    3.0  1095.0
# 4         0.0  2019-01-03     150-5003-069    1.0  1095.0

# %%
df["num_id"] = df["part_num"] + " _ " + df["sap_id"].map(str)

# %%
df=df.drop(["part_num","sap_id"],axis=1)

# %%
df.shape
# Out:
# (82219, 4)

# %%
df=df.groupby('num_id').head(1)
df
# Out:
#         base_price        date  count                      num_id
# 0           0.0000  2019-01-03    1.0       613-1340-001 _ 1095.0
# 1           0.0000  2019-01-03    1.0       434-0015-013 _ 1095.0
# 2           0.0000  2019-01-03    1.0    HS0-508BRH-Q//G _ 1095.0
# 3           0.0000  2019-01-03    3.0       440-1172-001 _ 1095.0
# 4           0.0000  2019-01-03    1.0       150-5003-069 _ 1095.0
# 5           0.0000  2019-01-03    1.0       652-0359-001 _ 1095.0
# 6           0.0000  2019-01-03    1.0       652-0359-002 _ 1095.0
# 7           0.0000  2019-01-03    1.0       653-8034-003 _ 1095.0
# 8           0.0000  2019-01-03    1.0       654-8230-002 _ 1095.0
# 9           0.0000  2019-01-03    1.0       151-5033-511 _ 1095.0
# 10          0.0000  2019-01-03    1.0       320-0001-015 _ 1095.0
# 11          0.0000  2019-01-03    1.0       509-2005-009 _ 1095.0
# 12          0.0000  2019-01-03    2.0       68010653-001 _ 1095.0
# ...

# %%
df.shape
# Out:
# (42462, 4)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.sort_values(by='date',ascending=True)
df
# Out:
#        base_price       date  count                      num_id
# 60347    121.9208 2019-01-01    2.0          8531178-1 _ 1073.0
# 77218   2074.4800 2019-01-01    2.0    10147526-101SUB _ 1064.0
# 44441     21.7183 2019-01-01    2.0          4073796-7 _ 5210.0
# 77234   2080.6820 2019-01-01    2.0          91-0807-1 _ 1600.0
# 77237   2082.2300 2019-01-01    1.0       722-4223-013 _ 5253.0
# 77263   2091.8340 2019-01-01    1.0       34209277-005 _ 1039.0
# 56193     75.0000 2019-01-01    1.0           04003310 _ 1006.0
# 64656    219.5944 2019-01-01    2.0        7519272-901 _ 1103.0
# 77306   2116.4629 2019-01-01    2.0   7036319-1905//CM _ 5210.0
# 77310   2118.7500 2019-01-01    1.0  34209400-TB44-001 _ 1039.0
# 64643    219.3600 2019-01-01    1.0        7022141-804 _ 5210.0
# 56230     75.1536 2019-01-01    2.0       704-2830-002 _ 1095.0
# 77212   2072.8706 2019-01-01    2.0        7516129-913 _ 1009.0
# 77337   2137.7029 2019-01-01    2.0         73000146-9 _ 1073.0
# ...

# %%
# df.sort_values("date", axis = 1, ascending = True, 
#                  inplace = True) 

# df.groupby(df['date'].dt.strftime('%B'))['num_id'].sort_values()

# %%
df.set_index('date', drop=True, append=False, inplace=True, verify_integrity=False)
df = df.sort_index()

# %%
df=df.groupby('num_id').head(1)
df
# Out:
#             base_price  count                      num_id
# date
# 2019-01-01    121.9208    2.0          8531178-1 _ 1073.0
# 2019-01-01   2074.4800    2.0    10147526-101SUB _ 1064.0
# 2019-01-01     21.7183    2.0          4073796-7 _ 5210.0
# 2019-01-01   2080.6820    2.0          91-0807-1 _ 1600.0
# 2019-01-01   2082.2300    1.0       722-4223-013 _ 5253.0
# 2019-01-01   2091.8340    1.0       34209277-005 _ 1039.0
# 2019-01-01     75.0000    1.0           04003310 _ 1006.0
# 2019-01-01    219.5944    2.0        7519272-901 _ 1103.0
# 2019-01-01   2116.4629    2.0   7036319-1905//CM _ 5210.0
# 2019-01-01   2118.7500    1.0  34209400-TB44-001 _ 1039.0
# 2019-01-01    219.3600    1.0        7022141-804 _ 5210.0
# 2019-01-01     75.1536    2.0       704-2830-002 _ 1095.0
# 2019-01-01   2072.8706    2.0        7516129-913 _ 1009.0
# 2019-01-01   2137.7029    2.0         73000146-9 _ 1073.0
# 2019-01-01   2148.6400    1.0          2815262-2 _ 1008.0
# ...

# %%
df.to_csv("C:\\Users\\piyul\\Desktop\\kaggle\\filtered_dataset_5.csv")
